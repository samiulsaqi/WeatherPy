# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# imports the previous directory for config.py
import sys
sys.path.insert(1, '../')

from citipy import citipy
from config import weather_database_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lams = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lams, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_database_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | fasa
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | sitka
# Processing Record 6 of Set 1 | itarema
# Processing Record 7 of Set 1 | stawell
# Processing Record 8 of Set 1 | takoradi
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | leh
# Processing Record 11 of Set 1 | limon
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | vanimo
# Processing Record 15 of Set 1 | eureka
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | hirara
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | saint-pierre
# Processing Record 22 of Set 1 | lake elsinore
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | novikovo
# Processing Record 26 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | sao jose da coroa grande
# Processing Record 31 of Set 1 | raymond
# Processing Record 32 of Set 1 | pitimbu
# Processing Record 33 of Set 1 | namibe
# Processing Record 34 of Set 1 | mahajanga
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | lima
# Processing Record 37 of Set 1 | namatanai
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | san patricio
# Processing Record 40 of Set 1 | awbari
# Processing Record 41 of Set 1 | kafue
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | half moon bay
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | naranjal
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | noumea
# Processing Record 3 of Set 2 | bathsheba
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | brazzaville
# Processing Record 6 of Set 2 | pallipattu
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | sangmelima
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | samarai
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | atambua
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | laredo
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | harrisburg
# Processing Record 21 of Set 2 | wonthaggi
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | iranshahr
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | tolga
# Processing Record 27 of Set 2 | dukat
# Processing Record 28 of Set 2 | north bend
# Processing Record 29 of Set 2 | tiznit
# Processing Record 30 of Set 2 | high rock
# Processing Record 31 of Set 2 | temple
# Processing Record 32 of Set 2 | lavrentiya
# Processing Record 33 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 2 | san cristobal
# Processing Record 36 of Set 2 | manacapuru
# Processing Record 37 of Set 2 | mudgee
# Processing Record 38 of Set 2 | yulara
# Processing Record 39 of Set 2 | valer
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 49 of Set 2 | ous
# Processing Record 50 of Set 2 | hokitika
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | odweyne
# Processing Record 4 of Set 3 | juneau
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | atar
# Processing Record 7 of Set 3 | stillwater
# Processing Record 8 of Set 3 | boshnyakovo
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | kabanjahe
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | zhigansk
# Processing Record 13 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 3 | ulaangom
# Processing Record 15 of Set 3 | alice springs
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | grand gaube
# Processing Record 19 of Set 3 | khuzhir
# Processing Record 20 of Set 3 | gizo
# Processing Record 21 of Set 3 | udachnyy
# Processing Record 22 of Set 3 | mae sot
# Processing Record 23 of Set 3 | port hardy
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 26 of Set 3 | sinop
# Processing Record 27 of Set 3 | paraguacu
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | kuytun
# Processing Record 34 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 3 | teya
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | hualmay
# Processing Record 39 of Set 3 | magistralnyy
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | cortez
# Processing Record 42 of Set 3 | podstepki
# Processing Record 43 of Set 3 | sinnamary
# Processing Record 44 of Set 3 | dunedin
# Processing Record 45 of Set 3 | sur
# Processing Record 46 of Set 3 | sao gabriel da cachoeira
# Processing Record 47 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 3 | nkowakowa
# Processing Record 50 of Set 3 | vila
# Processing Record 1 of Set 4 | tobermory
# Processing Record 2 of Set 4 | bobovdol
# Processing Record 3 of Set 4 | kahului
# Processing Record 4 of Set 4 | posyet
# Processing Record 5 of Set 4 | ostrovnoy
# Processing Record 6 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | west des moines
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | puerto leguizamo
# Processing Record 11 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 4 | ambulu
# Processing Record 13 of Set 4 | hofn
# Processing Record 14 of Set 4 | manaus
# Processing Record 15 of Set 4 | tabou
# Processing Record 16 of Set 4 | belmonte
# Processing Record 17 of Set 4 | grindavik
# Processing Record 18 of Set 4 | yumen
# Processing Record 19 of Set 4 | bentong
# Processing Record 20 of Set 4 | juxtlahuaca
# Processing Record 21 of Set 4 | maryborough
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | narsaq
# Processing Record 24 of Set 4 | broome
# Processing Record 25 of Set 4 | gold coast
# Processing Record 26 of Set 4 | srednekolymsk
# Processing Record 27 of Set 4 | banjar
# Processing Record 28 of Set 4 | talcahuano
# Processing Record 29 of Set 4 | havelock
# Processing Record 30 of Set 4 | yining
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | xichang
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | praia
# Processing Record 35 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 4 | rabo de peixe
# Processing Record 37 of Set 4 | cabinda
# Processing Record 38 of Set 4 | pangnirtung
# Processing Record 39 of Set 4 | tawnat
# City not found. Skipping...
# Processing Record 40 of Set 4 | oussouye
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | deputatskiy
# Processing Record 44 of Set 4 | amahai
# Processing Record 45 of Set 4 | dipkarpaz
# City not found. Skipping...
# Processing Record 46 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | praia da vitoria
# Processing Record 49 of Set 4 | saint-augustin
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | labuhan
# Processing Record 2 of Set 5 | trinidad
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | ucluelet
# Processing Record 8 of Set 5 | miraflores
# Processing Record 9 of Set 5 | northam
# Processing Record 10 of Set 5 | broken hill
# Processing Record 11 of Set 5 | leirvik
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | baruun-urt
# Processing Record 14 of Set 5 | bay roberts
# Processing Record 15 of Set 5 | mancio lima
# Processing Record 16 of Set 5 | suluq
# Processing Record 17 of Set 5 | romodanovo
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | thohoyandou
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | puerto ayacucho
# Processing Record 22 of Set 5 | buchanan
# Processing Record 23 of Set 5 | chanika
# Processing Record 24 of Set 5 | dawei
# Processing Record 25 of Set 5 | bow island
# Processing Record 26 of Set 5 | nuuk
# Processing Record 27 of Set 5 | cape coast
# Processing Record 28 of Set 5 | andros
# Processing Record 29 of Set 5 | qaanaaq
# Processing Record 30 of Set 5 | adrar
# Processing Record 31 of Set 5 | poum
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | yeppoon
# Processing Record 34 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 35 of Set 5 | sabha
# Processing Record 36 of Set 5 | chapleau
# Processing Record 37 of Set 5 | taltal
# Processing Record 38 of Set 5 | dombarovskiy
# Processing Record 39 of Set 5 | paka
# Processing Record 40 of Set 5 | roma
# Processing Record 41 of Set 5 | verkhniye sergi
# Processing Record 42 of Set 5 | fuyu
# Processing Record 43 of Set 5 | itoman
# Processing Record 44 of Set 5 | castro
# Processing Record 45 of Set 5 | henties bay
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | biak
# Processing Record 48 of Set 5 | vostok
# Processing Record 49 of Set 5 | bihariganj
# Processing Record 50 of Set 5 | kamaishi
# Processing Record 1 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 6 | port-gentil
# Processing Record 3 of Set 6 | gap
# Processing Record 4 of Set 6 | sao felix do xingu
# Processing Record 5 of Set 6 | plaeng yao
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 6 | leningradskiy
# Processing Record 8 of Set 6 | santarem
# Processing Record 9 of Set 6 | tessalit
# Processing Record 10 of Set 6 | richards bay
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | cayenne
# Processing Record 13 of Set 6 | alofi
# Processing Record 14 of Set 6 | awjilah
# Processing Record 15 of Set 6 | agadir
# Processing Record 16 of Set 6 | nipawin
# Processing Record 17 of Set 6 | bambous virieux
# Processing Record 18 of Set 6 | vestmannaeyjar
# Processing Record 19 of Set 6 | jiaonan
# Processing Record 20 of Set 6 | kalmunai
# Processing Record 21 of Set 6 | huanan
# Processing Record 22 of Set 6 | norman wells
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | shu
# Processing Record 25 of Set 6 | aksaray
# Processing Record 26 of Set 6 | sennoy
# Processing Record 27 of Set 6 | bihoro
# Processing Record 28 of Set 6 | halifax
# Processing Record 29 of Set 6 | egvekinot
# Processing Record 30 of Set 6 | del rio
# Processing Record 31 of Set 6 | sola
# Processing Record 32 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 6 | khatanga
# Processing Record 34 of Set 6 | ayan
# Processing Record 35 of Set 6 | walvis bay
# Processing Record 36 of Set 6 | belaya gora
# Processing Record 37 of Set 6 | smithers
# Processing Record 38 of Set 6 | kodiak
# Processing Record 39 of Set 6 | sorong
# Processing Record 40 of Set 6 | owensboro
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | provideniya
# Processing Record 43 of Set 6 | miyako
# Processing Record 44 of Set 6 | coquimbo
# Processing Record 45 of Set 6 | naryan-mar
# Processing Record 46 of Set 6 | san jeronimo
# Processing Record 47 of Set 6 | jacqueville
# Processing Record 48 of Set 6 | panguna
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | anaconda
# Processing Record 1 of Set 7 | vila velha
# Processing Record 2 of Set 7 | divnogorsk
# Processing Record 3 of Set 7 | saint george
# Processing Record 4 of Set 7 | korla
# Processing Record 5 of Set 7 | pemangkat
# Processing Record 6 of Set 7 | luena
# Processing Record 7 of Set 7 | klaksvik
# Processing Record 8 of Set 7 | raudeberg
# Processing Record 9 of Set 7 | luwuk
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | bundaberg
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | twentynine palms
# Processing Record 14 of Set 7 | jutai
# Processing Record 15 of Set 7 | dandong
# Processing Record 16 of Set 7 | lar
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | rangapara
# Processing Record 19 of Set 7 | presidencia roque saenz pena
# Processing Record 20 of Set 7 | eyl
# Processing Record 21 of Set 7 | cap-aux-meules
# Processing Record 22 of Set 7 | lata
# Processing Record 23 of Set 7 | iringa
# Processing Record 24 of Set 7 | teknaf
# Processing Record 25 of Set 7 | tamazulapam
# City not found. Skipping...
# Processing Record 26 of Set 7 | esperance
# Processing Record 27 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 28 of Set 7 | hobyo
# Processing Record 29 of Set 7 | urumqi
# Processing Record 30 of Set 7 | pangai
# Processing Record 31 of Set 7 | olinda
# Processing Record 32 of Set 7 | tomatlan
# Processing Record 33 of Set 7 | dalvik
# Processing Record 34 of Set 7 | elat
# Processing Record 35 of Set 7 | turukhansk
# Processing Record 36 of Set 7 | moose factory
# Processing Record 37 of Set 7 | innisfail
# Processing Record 38 of Set 7 | mitsamiouli
# Processing Record 39 of Set 7 | witham
# Processing Record 40 of Set 7 | rawson
# Processing Record 41 of Set 7 | houma
# Processing Record 42 of Set 7 | arlit
# Processing Record 43 of Set 7 | odesskoye
# Processing Record 44 of Set 7 | faanui
# Processing Record 45 of Set 7 | wahpeton
# Processing Record 46 of Set 7 | jaipur hat
# City not found. Skipping...
# Processing Record 47 of Set 7 | ilulissat
# Processing Record 48 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | havre-saint-pierre
# Processing Record 50 of Set 7 | golkoy
# Processing Record 1 of Set 8 | aklavik
# Processing Record 2 of Set 8 | la peca
# Processing Record 3 of Set 8 | honiton
# Processing Record 4 of Set 8 | oristano
# Processing Record 5 of Set 8 | marfino
# Processing Record 6 of Set 8 | cururupu
# Processing Record 7 of Set 8 | tigil
# Processing Record 8 of Set 8 | teguldet
# Processing Record 9 of Set 8 | jacareacanga
# Processing Record 10 of Set 8 | nouadhibou
# Processing Record 11 of Set 8 | mehamn
# Processing Record 12 of Set 8 | bakel
# Processing Record 13 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 8 | poronaysk
# Processing Record 15 of Set 8 | gazli
# Processing Record 16 of Set 8 | gotemba
# Processing Record 17 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 8 | nouakchott
# Processing Record 19 of Set 8 | vestmanna
# Processing Record 20 of Set 8 | warrnambool
# Processing Record 21 of Set 8 | porto nacional
# Processing Record 22 of Set 8 | paamiut
# Processing Record 23 of Set 8 | casas grandes
# Processing Record 24 of Set 8 | tsevie
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | gweta
# Processing Record 27 of Set 8 | dzheyrakh
# Processing Record 28 of Set 8 | champerico
# Processing Record 29 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 8 | graham
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | kashi
# Processing Record 33 of Set 8 | bambanglipuro
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | kyren
# Processing Record 36 of Set 8 | yanam
# Processing Record 37 of Set 8 | saldanha
# Processing Record 38 of Set 8 | santona
# Processing Record 39 of Set 8 | port hedland
# Processing Record 40 of Set 8 | kurumkan
# Processing Record 41 of Set 8 | saint marys
# Processing Record 42 of Set 8 | baykit
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | harnosand
# Processing Record 45 of Set 8 | port elizabeth
# Processing Record 46 of Set 8 | gucheng
# Processing Record 47 of Set 8 | kudat
# Processing Record 48 of Set 8 | kuryk
# Processing Record 49 of Set 8 | delicias
# Processing Record 50 of Set 8 | muros
# Processing Record 1 of Set 9 | siloam springs
# Processing Record 2 of Set 9 | souillac
# Processing Record 3 of Set 9 | prainha
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | nelson bay
# Processing Record 6 of Set 9 | taperoa
# Processing Record 7 of Set 9 | armizonskoye
# Processing Record 8 of Set 9 | emerald
# Processing Record 9 of Set 9 | urfa
# City not found. Skipping...
# Processing Record 10 of Set 9 | nea mikhaniona
# City not found. Skipping...
# Processing Record 11 of Set 9 | qatana
# Processing Record 12 of Set 9 | imamoglu
# Processing Record 13 of Set 9 | bollnas
# Processing Record 14 of Set 9 | kostino
# Processing Record 15 of Set 9 | nalut
# Processing Record 16 of Set 9 | carballo
# Processing Record 17 of Set 9 | iquique
# Processing Record 18 of Set 9 | naze
# Processing Record 19 of Set 9 | gravdal
# Processing Record 20 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 9 | nemuro
# Processing Record 22 of Set 9 | alugan
# Processing Record 23 of Set 9 | urgut
# Processing Record 24 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 25 of Set 9 | la sarre
# Processing Record 26 of Set 9 | zykovo
# Processing Record 27 of Set 9 | lida
# Processing Record 28 of Set 9 | gunjur
# Processing Record 29 of Set 9 | mamontovo
# Processing Record 30 of Set 9 | ozark
# Processing Record 31 of Set 9 | korsakov
# Processing Record 32 of Set 9 | methven
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | hervey bay
# Processing Record 35 of Set 9 | pokanayevka
# City not found. Skipping...
# Processing Record 36 of Set 9 | el alto
# Processing Record 37 of Set 9 | ryotsu
# Processing Record 38 of Set 9 | lincoln
# Processing Record 39 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 9 | suntar
# Processing Record 41 of Set 9 | contai
# Processing Record 42 of Set 9 | kalemie
# Processing Record 43 of Set 9 | bonaventure
# Processing Record 44 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 45 of Set 9 | lasa
# Processing Record 46 of Set 9 | zeya
# Processing Record 47 of Set 9 | boca do acre
# Processing Record 48 of Set 9 | east wenatchee bench
# Processing Record 49 of Set 9 | boulder
# Processing Record 50 of Set 9 | pedernales
# Processing Record 1 of Set 10 | la ronge
# Processing Record 2 of Set 10 | clearlake
# Processing Record 3 of Set 10 | mwingi
# Processing Record 4 of Set 10 | rabat
# Processing Record 5 of Set 10 | shimoda
# Processing Record 6 of Set 10 | kjollefjord
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | shingu
# Processing Record 9 of Set 10 | vao
# Processing Record 10 of Set 10 | muzhi
# Processing Record 11 of Set 10 | banda aceh
# Processing Record 12 of Set 10 | ust-tsilma
# Processing Record 13 of Set 10 | mayo
# Processing Record 14 of Set 10 | lons
# Processing Record 15 of Set 10 | valentin gomez farias
# Processing Record 16 of Set 10 | garissa
# Processing Record 17 of Set 10 | fitii
# Processing Record 18 of Set 10 | bonnyville
# Processing Record 19 of Set 10 | kaspi
# Processing Record 20 of Set 10 | sabancuy
# Processing Record 21 of Set 10 | nador
# Processing Record 22 of Set 10 | voh
# Processing Record 23 of Set 10 | tasiilaq
# Processing Record 24 of Set 10 | ati
# Processing Record 25 of Set 10 | husavik
# Processing Record 26 of Set 10 | pingliang
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | acapulco
# Processing Record 29 of Set 10 | taoudenni
# Processing Record 30 of Set 10 | moron
# Processing Record 31 of Set 10 | san vicente
# Processing Record 32 of Set 10 | skibbereen
# Processing Record 33 of Set 10 | hambantota
# Processing Record 34 of Set 10 | mangrol
# Processing Record 35 of Set 10 | dhangadhi
# Processing Record 36 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 10 | pinawa
# Processing Record 38 of Set 10 | ancud
# Processing Record 39 of Set 10 | neiafu
# Processing Record 40 of Set 10 | nagato
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | nioro
# Processing Record 43 of Set 10 | sokolo
# Processing Record 44 of Set 10 | nizwa
# Processing Record 45 of Set 10 | pakokku
# Processing Record 46 of Set 10 | dingle
# Processing Record 47 of Set 10 | khani
# Processing Record 48 of Set 10 | mikhaylovskoye
# Processing Record 49 of Set 10 | george town
# Processing Record 50 of Set 10 | port blair
# Processing Record 1 of Set 11 | camacha
# Processing Record 2 of Set 11 | kirakira
# Processing Record 3 of Set 11 | yabrud
# Processing Record 4 of Set 11 | reitz
# Processing Record 5 of Set 11 | nizhniy tsasuchey
# Processing Record 6 of Set 11 | thinadhoo
# Processing Record 7 of Set 11 | dundee
# Processing Record 8 of Set 11 | caracollo
# Processing Record 9 of Set 11 | torbeyevo
# Processing Record 10 of Set 11 | banbury
# Processing Record 11 of Set 11 | esterhazy
# Processing Record 12 of Set 11 | touros
# Processing Record 13 of Set 11 | rafai
# Processing Record 14 of Set 11 | necochea
# Processing Record 15 of Set 11 | labuan
# Processing Record 16 of Set 11 | brigantine
# Processing Record 17 of Set 11 | carstairs
# Processing Record 18 of Set 11 | yenagoa
# Processing Record 19 of Set 11 | sumenep
# Processing Record 20 of Set 11 | karasuk
# Processing Record 21 of Set 11 | sibolga
# Processing Record 22 of Set 11 | birao
# Processing Record 23 of Set 11 | rio grande
# Processing Record 24 of Set 11 | ginda
# Processing Record 25 of Set 11 | mount isa
# Processing Record 26 of Set 11 | terrace
# Processing Record 27 of Set 11 | fare
# Processing Record 28 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 29 of Set 11 | sasebo
# Processing Record 30 of Set 11 | sept-iles
# Processing Record 31 of Set 11 | wittenheim
# Processing Record 32 of Set 11 | upata
# Processing Record 33 of Set 11 | port macquarie
# Processing Record 34 of Set 11 | veraval
# Processing Record 35 of Set 11 | vaovai
# City not found. Skipping...
# Processing Record 36 of Set 11 | lysychovo
# Processing Record 37 of Set 11 | palora
# Processing Record 38 of Set 11 | montepuez
# Processing Record 39 of Set 11 | buin
# Processing Record 40 of Set 11 | majene
# Processing Record 41 of Set 11 | pierre
# Processing Record 42 of Set 11 | zaysan
# Processing Record 43 of Set 11 | severo-yeniseyskiy
# Processing Record 44 of Set 11 | turka
# Processing Record 45 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 11 | mocuba
# Processing Record 47 of Set 11 | ocampo
# Processing Record 48 of Set 11 | navrongo
# Processing Record 49 of Set 11 | dengzhou
# Processing Record 50 of Set 11 | matagami
# Processing Record 1 of Set 12 | we
# City not found. Skipping...
# Processing Record 2 of Set 12 | mahanoro
# Processing Record 3 of Set 12 | usinsk
# Processing Record 4 of Set 12 | bereznik
# Processing Record 5 of Set 12 | pendleton
# Processing Record 6 of Set 12 | elizabeth city
# Processing Record 7 of Set 12 | cascais
# Processing Record 8 of Set 12 | agadez
# Processing Record 9 of Set 12 | moratuwa
# Processing Record 10 of Set 12 | utena
# Processing Record 11 of Set 12 | soyo
# Processing Record 12 of Set 12 | stavern
# Processing Record 13 of Set 12 | kloulklubed
# Processing Record 14 of Set 12 | kieta
# Processing Record 15 of Set 12 | placerville
# Processing Record 16 of Set 12 | laguna
# Processing Record 17 of Set 12 | burnie
# Processing Record 18 of Set 12 | ngunguru
# Processing Record 19 of Set 12 | high level
# Processing Record 20 of Set 12 | wajir
# Processing Record 21 of Set 12 | guerrero negro
# Processing Record 22 of Set 12 | fernley
# Processing Record 23 of Set 12 | varhaug
# Processing Record 24 of Set 12 | nyimba
# Processing Record 25 of Set 12 | san rafael
# Processing Record 26 of Set 12 | watsa
# Processing Record 27 of Set 12 | comodoro rivadavia
# Processing Record 28 of Set 12 | sadasivpet
# Processing Record 29 of Set 12 | quelimane
# Processing Record 30 of Set 12 | mossendjo
# Processing Record 31 of Set 12 | pisco
# Processing Record 32 of Set 12 | port lincoln
# Processing Record 33 of Set 12 | kavieng
# Processing Record 34 of Set 12 | motril
# Processing Record 35 of Set 12 | sovetskiy
# Processing Record 36 of Set 12 | svetlaya
# Processing Record 37 of Set 12 | severo-kurilsk
# Processing Record 38 of Set 12 | puksoozero
# Processing Record 39 of Set 12 | manggar
# Processing Record 40 of Set 12 | son la
# Processing Record 41 of Set 12 | port moresby
# Processing Record 42 of Set 12 | cockburn town
# Processing Record 43 of Set 12 | leshukonskoye
# Processing Record 44 of Set 12 | arkansas city
# Processing Record 45 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 12 | melita
# Processing Record 47 of Set 12 | sao miguel
# Processing Record 48 of Set 12 | wanning
# Processing Record 49 of Set 12 | makakilo city
# Processing Record 50 of Set 12 | bam
# Processing Record 1 of Set 13 | canita
# Processing Record 2 of Set 13 | marmaris
# Processing Record 3 of Set 13 | slonim
# Processing Record 4 of Set 13 | palmer
# Processing Record 5 of Set 13 | garowe
# Processing Record 6 of Set 13 | tara
# Processing Record 7 of Set 13 | ponta delgada
# Processing Record 8 of Set 13 | herat
# Processing Record 9 of Set 13 | iqaluit
# Processing Record 10 of Set 13 | leon valley
# Processing Record 11 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 13 | kitimat
# Processing Record 13 of Set 13 | phalodi
# Processing Record 14 of Set 13 | aksarka
# Processing Record 15 of Set 13 | ishigaki
# Processing Record 16 of Set 13 | makhalino
# Processing Record 17 of Set 13 | anadyr
# Processing Record 18 of Set 13 | nisia floresta
# Processing Record 19 of Set 13 | puerto baquerizo moreno
# Processing Record 20 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 21 of Set 13 | assiniboia
# Processing Record 22 of Set 13 | bandarbeyla
# Processing Record 23 of Set 13 | aksha
# Processing Record 24 of Set 13 | narok
# Processing Record 25 of Set 13 | xuchang
# Processing Record 26 of Set 13 | lagos
# Processing Record 27 of Set 13 | muisne
# Processing Record 28 of Set 13 | verkhniy baskunchak
# Processing Record 29 of Set 13 | natchitoches
# Processing Record 30 of Set 13 | dicabisagan
# Processing Record 31 of Set 13 | barroquinha
# Processing Record 32 of Set 13 | saint pete beach
# Processing Record 33 of Set 13 | yar-sale
# Processing Record 34 of Set 13 | sunbury
# Processing Record 35 of Set 13 | barcelos
# Processing Record 36 of Set 13 | vondrozo
# Processing Record 37 of Set 13 | malanje
# Processing Record 38 of Set 13 | dhidhdhoo
# Processing Record 39 of Set 13 | denpasar
# Processing Record 40 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 41 of Set 13 | bembereke
# Processing Record 42 of Set 13 | saint-francois
# Processing Record 43 of Set 13 | sao filipe
# Processing Record 44 of Set 13 | dogondoutchi
# Processing Record 45 of Set 13 | dauphin
# Processing Record 46 of Set 13 | komsomolskiy
# Processing Record 47 of Set 13 | tombouctou
# Processing Record 48 of Set 13 | gualaquiza
# Processing Record 49 of Set 13 | tautira
# Processing Record 50 of Set 13 | antalaha
# Processing Record 1 of Set 14 | khoy
# Processing Record 2 of Set 14 | gzhatsk
# City not found. Skipping...
# Processing Record 3 of Set 14 | tual
# Processing Record 4 of Set 14 | barinitas
# Processing Record 5 of Set 14 | marzuq
# Processing Record 6 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 14 | gornopravdinsk
# Processing Record 8 of Set 14 | guanaja
# Processing Record 9 of Set 14 | aksehir
# Processing Record 10 of Set 14 | qunduz
# Processing Record 11 of Set 14 | najran
# Processing Record 12 of Set 14 | jega
# Processing Record 13 of Set 14 | luangwa
# Processing Record 14 of Set 14 | orissaare
# Processing Record 15 of Set 14 | bilma
# Processing Record 16 of Set 14 | senden
# Processing Record 17 of Set 14 | bilibino
# Processing Record 18 of Set 14 | porto walter
# Processing Record 19 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 14 | ola
# Processing Record 22 of Set 14 | srandakan
# Processing Record 23 of Set 14 | antofagasta
# Processing Record 24 of Set 14 | lafiagi
# Processing Record 25 of Set 14 | tilichiki
# Processing Record 26 of Set 14 | vanavara
# Processing Record 27 of Set 14 | atbasar
# Processing Record 28 of Set 14 | caravelas
# Processing Record 29 of Set 14 | derzhavinsk
# Processing Record 30 of Set 14 | duma
# Processing Record 31 of Set 14 | abalak
# Processing Record 32 of Set 14 | saint-leu
# Processing Record 33 of Set 14 | oceanside
# Processing Record 34 of Set 14 | koluszki
# Processing Record 35 of Set 14 | palauig
# Processing Record 36 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 14 | hendek
# Processing Record 38 of Set 14 | vagamo
# Processing Record 39 of Set 14 | kargil
# Processing Record 40 of Set 14 | harper
# Processing Record 41 of Set 14 | quchan
# Processing Record 42 of Set 14 | belousovka
# Processing Record 43 of Set 14 | villefranche-sur-saone
# Processing Record 44 of Set 14 | miyazu
# Processing Record 45 of Set 14 | manokwari
# Processing Record 46 of Set 14 | raychikhinsk
# Processing Record 47 of Set 14 | paita
# Processing Record 48 of Set 14 | opuwo
# Processing Record 49 of Set 14 | nacala
# Processing Record 50 of Set 14 | saint-georges
# Processing Record 1 of Set 15 | ust-kuyga
# Processing Record 2 of Set 15 | asau
# Processing Record 3 of Set 15 | san carlos
# Processing Record 4 of Set 15 | san policarpo
# Processing Record 5 of Set 15 | agirish
# Processing Record 6 of Set 15 | braedstrup
# Processing Record 7 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 15 | shumskiy
# Processing Record 9 of Set 15 | ningan
# City not found. Skipping...
# Processing Record 10 of Set 15 | esil
# Processing Record 11 of Set 15 | malpe
# Processing Record 12 of Set 15 | port shepstone
# Processing Record 13 of Set 15 | toshkivka
# Processing Record 14 of Set 15 | tura
# Processing Record 15 of Set 15 | brae
# Processing Record 16 of Set 15 | kununurra
# Processing Record 17 of Set 15 | gemena
# Processing Record 18 of Set 15 | maun
# Processing Record 19 of Set 15 | kenai
# Processing Record 20 of Set 15 | russell
# Processing Record 21 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 15 | gat
# Processing Record 23 of Set 15 | christchurch
# Processing Record 24 of Set 15 | coihaique
# Processing Record 25 of Set 15 | porto novo
# Processing Record 26 of Set 15 | maniitsoq
# Processing Record 27 of Set 15 | serro
# Processing Record 28 of Set 15 | xinye
# Processing Record 29 of Set 15 | rorvik
# Processing Record 30 of Set 15 | keflavik
# Processing Record 31 of Set 15 | darhan
# Processing Record 32 of Set 15 | hamilton
# Processing Record 33 of Set 15 | paramonga
# Processing Record 34 of Set 15 | newala
# Processing Record 35 of Set 15 | miquelon
# Processing Record 36 of Set 15 | sandy bay
# Processing Record 37 of Set 15 | mao
# Processing Record 38 of Set 15 | mandurah
# Processing Record 39 of Set 15 | abu kamal
# Processing Record 40 of Set 15 | cantanhede
# Processing Record 41 of Set 15 | djambala
# Processing Record 42 of Set 15 | vargem grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# # # Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Hobart -42.88  147.33      59.0        58         100       11.41
# 1            Fasa  28.94   53.65      57.2        58          90        7.52
# 2  Saint-Philippe -21.36   55.77      77.0        78          20       10.29
# 3           Sitka  57.05 -135.33      33.8        80          90        3.36
# 4         Itarema  -2.92  -39.92      84.7        61           0       20.11
#
#   Country Current Description
# 0      AU     overcast clouds
# 1      IR     overcast clouds
# 2      RE          few clouds
# 3      US     overcast clouds
# 4      BR           clear sky

# %%
#reorder columns
new_col_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_col_order]
city_data_df
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hobart      AU -42.88  147.33     59.00        58         100
# 1              Fasa      IR  28.94   53.65     57.20        58          90
# 2    Saint-Philippe      RE -21.36   55.77     77.00        78          20
# 3             Sitka      US  57.05 -135.33     33.80        80          90
# 4           Itarema      BR  -2.92  -39.92     84.70        61           0
# ..              ...     ...    ...     ...       ...       ...         ...
# 675        Mandurah      AU -32.55  115.70     55.99        70           0
# 676       Abu Kamal      SY  34.45   40.92     57.25        54          67
# 677      Cantanhede      BR  -3.63  -44.38     83.46        80         100
# 678        Djambala      CG  -2.54   14.75     69.31        96         100
# 679   Vargem Grande      BR  -3.54  -43.92     84.45        73         100
#
#      Wind Speed Current Description
# 0         11.41     overcast clouds
# 1          7.52     overcast clouds
# 2         10.29          few clouds
# 3          3.36     overcast clouds
# 4         20.11           clear sky
# ..          ...                 ...
# 675       13.49           clear sky
# 676        3.38       broken clouds
# 677        0.81     overcast clouds
# 678        3.53     overcast clouds
# 679        3.27     overcast clouds
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index ="City")
