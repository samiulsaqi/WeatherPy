# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# imports the previous directory for config.py
import sys
sys.path.insert(1, '../')

from citipy import citipy
from config import weather_database_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lams = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lams, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_database_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ity not found. Skipping...
# Processing Record 10 of Set 7 | yairipok
# Processing Record 11 of Set 7 | synya
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | butaritari
# Processing Record 15 of Set 7 | itoman
# Processing Record 16 of Set 7 | ures
# Processing Record 17 of Set 7 | santa vitoria do palmar
# Processing Record 18 of Set 7 | libano
# Processing Record 19 of Set 7 | drumheller
# Processing Record 20 of Set 7 | port augusta
# Processing Record 21 of Set 7 | tabuk
# Processing Record 22 of Set 7 | necaxa
# Processing Record 23 of Set 7 | veraval
# Processing Record 24 of Set 7 | lagoa
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | nome
# Processing Record 27 of Set 7 | ukiah
# Processing Record 28 of Set 7 | gorontalo
# Processing Record 29 of Set 7 | san borja
# Processing Record 30 of Set 7 | odweyne
# Processing Record 31 of Set 7 | mount gambier
# Processing Record 32 of Set 7 | ntcheu
# Processing Record 33 of Set 7 | manavgat
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | novaya bryan
# Processing Record 36 of Set 7 | vestmannaeyjar
# Processing Record 37 of Set 7 | yelizovo
# Processing Record 38 of Set 7 | deer lake
# Processing Record 39 of Set 7 | bogorodskoye
# Processing Record 40 of Set 7 | gibara
# Processing Record 41 of Set 7 | birjand
# Processing Record 42 of Set 7 | nouadhibou
# Processing Record 43 of Set 7 | jinchang
# Processing Record 44 of Set 7 | williston
# Processing Record 45 of Set 7 | henties bay
# Processing Record 46 of Set 7 | krasnogvardeyskoye
# Processing Record 47 of Set 7 | honjo
# Processing Record 48 of Set 7 | saldanha
# Processing Record 49 of Set 7 | kirksville
# Processing Record 50 of Set 7 | scottsbluff
# Processing Record 1 of Set 8 | oum hadjer
# Processing Record 2 of Set 8 | kavieng
# Processing Record 3 of Set 8 | faya
# Processing Record 4 of Set 8 | nobres
# Processing Record 5 of Set 8 | mehamn
# Processing Record 6 of Set 8 | ust-tsilma
# Processing Record 7 of Set 8 | rorvik
# Processing Record 8 of Set 8 | sola
# Processing Record 9 of Set 8 | tahta
# Processing Record 10 of Set 8 | tasiilaq
# Processing Record 11 of Set 8 | vestmanna
# Processing Record 12 of Set 8 | alofi
# Processing Record 13 of Set 8 | zhetybay
# City not found. Skipping...
# Processing Record 14 of Set 8 | picui
# Processing Record 15 of Set 8 | mora
# Processing Record 16 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | myaundzha
# Processing Record 18 of Set 8 | marevo
# Processing Record 19 of Set 8 | yuzhnyy
# Processing Record 20 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 8 | tiksi
# Processing Record 22 of Set 8 | general pico
# Processing Record 23 of Set 8 | kovernino
# Processing Record 24 of Set 8 | phuket
# Processing Record 25 of Set 8 | jawa
# Processing Record 26 of Set 8 | kungurtug
# Processing Record 27 of Set 8 | sorland
# Processing Record 28 of Set 8 | arandis
# Processing Record 29 of Set 8 | xinglongshan
# Processing Record 30 of Set 8 | yerbogachen
# Processing Record 31 of Set 8 | lima
# Processing Record 32 of Set 8 | valparaiso
# Processing Record 33 of Set 8 | kabanjahe
# Processing Record 34 of Set 8 | coihaique
# Processing Record 35 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 8 | severo-yeniseyskiy
# Processing Record 37 of Set 8 | ostrovnoy
# Processing Record 38 of Set 8 | talara
# Processing Record 39 of Set 8 | tual
# Processing Record 40 of Set 8 | porbandar
# Processing Record 41 of Set 8 | kirovskiy
# Processing Record 42 of Set 8 | comodoro rivadavia
# Processing Record 43 of Set 8 | bonavista
# Processing Record 44 of Set 8 | iralaya
# Processing Record 45 of Set 8 | soni
# Processing Record 46 of Set 8 | halifax
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | fujinomiya
# Processing Record 49 of Set 8 | kahului
# Processing Record 50 of Set 8 | zakharovo
# Processing Record 1 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 9 | dalnerechensk
# Processing Record 3 of Set 9 | katsuura
# Processing Record 4 of Set 9 | gamba
# Processing Record 5 of Set 9 | atikokan
# Processing Record 6 of Set 9 | mogadishu
# Processing Record 7 of Set 9 | matara
# Processing Record 8 of Set 9 | buchanan
# Processing Record 9 of Set 9 | atakpame
# Processing Record 10 of Set 9 | rosarito
# Processing Record 11 of Set 9 | san cristobal
# Processing Record 12 of Set 9 | berlevag
# Processing Record 13 of Set 9 | tarakan
# Processing Record 14 of Set 9 | broome
# Processing Record 15 of Set 9 | yar-sale
# Processing Record 16 of Set 9 | ninghai
# Processing Record 17 of Set 9 | tilichiki
# Processing Record 18 of Set 9 | tibati
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | kroya
# Processing Record 21 of Set 9 | manono
# Processing Record 22 of Set 9 | rawson
# Processing Record 23 of Set 9 | alyangula
# Processing Record 24 of Set 9 | vicuna
# Processing Record 25 of Set 9 | pacific grove
# Processing Record 26 of Set 9 | kirakira
# Processing Record 27 of Set 9 | sogdiondon
# City not found. Skipping...
# Processing Record 28 of Set 9 | verkhnevilyuysk
# Processing Record 29 of Set 9 | narsaq
# Processing Record 30 of Set 9 | poum
# Processing Record 31 of Set 9 | flinders
# Processing Record 32 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | samarai
# Processing Record 34 of Set 9 | aras
# Processing Record 35 of Set 9 | tete
# Processing Record 36 of Set 9 | pangnirtung
# Processing Record 37 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 9 | lichinga
# Processing Record 39 of Set 9 | makakilo city
# Processing Record 40 of Set 9 | yeppoon
# Processing Record 41 of Set 9 | ketchikan
# Processing Record 42 of Set 9 | butembo
# Processing Record 43 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 9 | mana
# Processing Record 45 of Set 9 | isla mujeres
# Processing Record 46 of Set 9 | gorgan
# Processing Record 47 of Set 9 | sesheke
# Processing Record 48 of Set 9 | muros
# Processing Record 49 of Set 9 | hervey bay
# Processing Record 50 of Set 9 | nabire
# Processing Record 1 of Set 10 | lasa
# Processing Record 2 of Set 10 | aktash
# Processing Record 3 of Set 10 | neiafu
# Processing Record 4 of Set 10 | lakes entrance
# Processing Record 5 of Set 10 | moctezuma
# Processing Record 6 of Set 10 | abnub
# Processing Record 7 of Set 10 | lourdes
# Processing Record 8 of Set 10 | port macquarie
# Processing Record 9 of Set 10 | mananjary
# Processing Record 10 of Set 10 | kuytun
# Processing Record 11 of Set 10 | dabat
# Processing Record 12 of Set 10 | sobolevo
# Processing Record 13 of Set 10 | claresholm
# Processing Record 14 of Set 10 | wattegama
# Processing Record 15 of Set 10 | groningen
# Processing Record 16 of Set 10 | geraldton
# Processing Record 17 of Set 10 | rafai
# Processing Record 18 of Set 10 | joaima
# Processing Record 19 of Set 10 | canas
# Processing Record 20 of Set 10 | benghazi
# Processing Record 21 of Set 10 | khatanga
# Processing Record 22 of Set 10 | vila franca do campo
# Processing Record 23 of Set 10 | chicama
# Processing Record 24 of Set 10 | petropavl
# Processing Record 25 of Set 10 | hofn
# Processing Record 26 of Set 10 | atasu
# Processing Record 27 of Set 10 | balkhash
# Processing Record 28 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 10 | taganak
# Processing Record 31 of Set 10 | saint-pierre
# Processing Record 32 of Set 10 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 10 | galesong
# Processing Record 34 of Set 10 | cayenne
# Processing Record 35 of Set 10 | torrelavega
# Processing Record 36 of Set 10 | bridlington
# Processing Record 37 of Set 10 | pinheiral
# Processing Record 38 of Set 10 | mandalgovi
# Processing Record 39 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 10 | fuyang
# Processing Record 41 of Set 10 | praya
# Processing Record 42 of Set 10 | altay
# Processing Record 43 of Set 10 | culaman
# Processing Record 44 of Set 10 | miles city
# Processing Record 45 of Set 10 | mandera
# Processing Record 46 of Set 10 | deputatskiy
# Processing Record 47 of Set 10 | salym
# Processing Record 48 of Set 10 | sidi ali
# Processing Record 49 of Set 10 | bambous virieux
# Processing Record 50 of Set 10 | whitecourt
# Processing Record 1 of Set 11 | sabanalarga
# Processing Record 2 of Set 11 | matagami
# Processing Record 3 of Set 11 | honghu
# Processing Record 4 of Set 11 | caravelas
# Processing Record 5 of Set 11 | benguela
# Processing Record 6 of Set 11 | mitu
# Processing Record 7 of Set 11 | uusikaupunki
# Processing Record 8 of Set 11 | palmer
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | saint george
# Processing Record 11 of Set 11 | leh
# Processing Record 12 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 14 of Set 11 | massakory
# Processing Record 15 of Set 11 | fountain hills
# Processing Record 16 of Set 11 | blacksburg
# Processing Record 17 of Set 11 | abu zabad
# Processing Record 18 of Set 11 | bahia honda
# Processing Record 19 of Set 11 | quatre cocos
# Processing Record 20 of Set 11 | waterloo
# Processing Record 21 of Set 11 | ahome
# Processing Record 22 of Set 11 | thap than
# Processing Record 23 of Set 11 | korop
# Processing Record 24 of Set 11 | waipawa
# Processing Record 25 of Set 11 | khoy
# Processing Record 26 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 11 | iskateley
# Processing Record 28 of Set 11 | saint anthony
# Processing Record 29 of Set 11 | klaksvik
# Processing Record 30 of Set 11 | labuhan
# Processing Record 31 of Set 11 | san quintin
# Processing Record 32 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 33 of Set 11 | ahipara
# Processing Record 34 of Set 11 | pundaguitan
# Processing Record 35 of Set 11 | lunca
# Processing Record 36 of Set 11 | recke
# Processing Record 37 of Set 11 | markova
# Processing Record 38 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 11 | gurupi
# Processing Record 40 of Set 11 | mount isa
# Processing Record 41 of Set 11 | reyes
# Processing Record 42 of Set 11 | marsh harbour
# Processing Record 43 of Set 11 | shira
# Processing Record 44 of Set 11 | tiarei
# Processing Record 45 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 11 | tubuala
# Processing Record 47 of Set 11 | jaipur
# Processing Record 48 of Set 11 | okoneshnikovo
# Processing Record 49 of Set 11 | angoche
# Processing Record 50 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 1 of Set 12 | touros
# Processing Record 2 of Set 12 | yinchuan
# Processing Record 3 of Set 12 | yarmouth
# Processing Record 4 of Set 12 | myitkyina
# Processing Record 5 of Set 12 | limon
# Processing Record 6 of Set 12 | tsaratanana
# Processing Record 7 of Set 12 | ayan
# Processing Record 8 of Set 12 | ijui
# Processing Record 9 of Set 12 | batemans bay
# Processing Record 10 of Set 12 | wanning
# Processing Record 11 of Set 12 | ovsyanka
# Processing Record 12 of Set 12 | temnikov
# Processing Record 13 of Set 12 | shelburne
# Processing Record 14 of Set 12 | aksha
# Processing Record 15 of Set 12 | nargana
# Processing Record 16 of Set 12 | japura
# Processing Record 17 of Set 12 | evanston
# Processing Record 18 of Set 12 | darab
# Processing Record 19 of Set 12 | pavilosta
# Processing Record 20 of Set 12 | latung
# Processing Record 21 of Set 12 | coahuayana
# Processing Record 22 of Set 12 | mahon
# Processing Record 23 of Set 12 | nizhneudinsk
# Processing Record 24 of Set 12 | merauke
# Processing Record 25 of Set 12 | luwuk
# Processing Record 26 of Set 12 | fethiye
# Processing Record 27 of Set 12 | san policarpo
# Processing Record 28 of Set 12 | puerto baquerizo moreno
# Processing Record 29 of Set 12 | rab
# City not found. Skipping...
# Processing Record 30 of Set 12 | uvalde
# Processing Record 31 of Set 12 | lompoc
# Processing Record 32 of Set 12 | norilsk
# Processing Record 33 of Set 12 | walvis bay
# Processing Record 34 of Set 12 | agadir
# Processing Record 35 of Set 12 | amahai
# Processing Record 36 of Set 12 | mvuma
# Processing Record 37 of Set 12 | kerema
# Processing Record 38 of Set 12 | paamiut
# Processing Record 39 of Set 12 | ngunguru
# Processing Record 40 of Set 12 | novyy urengoy
# Processing Record 41 of Set 12 | imbituba
# Processing Record 42 of Set 12 | gobabis
# Processing Record 43 of Set 12 | vrangel
# Processing Record 44 of Set 12 | viedma
# Processing Record 45 of Set 12 | bambanglipuro
# Processing Record 46 of Set 12 | forestville
# Processing Record 47 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 12 | visby
# Processing Record 49 of Set 12 | cave spring
# Processing Record 50 of Set 12 | hibbing
# Processing Record 1 of Set 13 | orlik
# Processing Record 2 of Set 13 | tari
# Processing Record 3 of Set 13 | annau
# Processing Record 4 of Set 13 | maldonado
# Processing Record 5 of Set 13 | lapithos
# Processing Record 6 of Set 13 | kasangulu
# Processing Record 7 of Set 13 | fairview
# Processing Record 8 of Set 13 | kachiry
# Processing Record 9 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 12 of Set 13 | okhotsk
# Processing Record 13 of Set 13 | zabol
# Processing Record 14 of Set 13 | kulhudhuffushi
# Processing Record 15 of Set 13 | takoradi
# Processing Record 16 of Set 13 | reserva
# Processing Record 17 of Set 13 | pathein
# Processing Record 18 of Set 13 | minab
# Processing Record 19 of Set 13 | carutapera
# Processing Record 20 of Set 13 | constitucion
# Processing Record 21 of Set 13 | rawah
# Processing Record 22 of Set 13 | pointe michel
# Processing Record 23 of Set 13 | betsiamites
# Processing Record 24 of Set 13 | teguise
# Processing Record 25 of Set 13 | mayumba
# Processing Record 26 of Set 13 | mackenzie
# Processing Record 27 of Set 13 | bundaberg
# Processing Record 28 of Set 13 | kozhva
# Processing Record 29 of Set 13 | kant
# Processing Record 30 of Set 13 | slyudyanka
# Processing Record 31 of Set 13 | mormugao
# Processing Record 32 of Set 13 | peno
# Processing Record 33 of Set 13 | santa cruz de la palma
# Processing Record 34 of Set 13 | bowen
# Processing Record 35 of Set 13 | shache
# Processing Record 36 of Set 13 | champerico
# Processing Record 37 of Set 13 | maumere
# Processing Record 38 of Set 13 | la asuncion
# Processing Record 39 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 13 | san joaquin
# Processing Record 41 of Set 13 | college
# Processing Record 42 of Set 13 | panaba
# Processing Record 43 of Set 13 | sibolga
# Processing Record 44 of Set 13 | kaniama
# Processing Record 45 of Set 13 | slonim
# Processing Record 46 of Set 13 | musiri
# Processing Record 47 of Set 13 | sulangan
# Processing Record 48 of Set 13 | whitehorse
# Processing Record 49 of Set 13 | benjamin constant
# Processing Record 50 of Set 13 | krasnyy chikoy
# Processing Record 1 of Set 14 | aripuana
# Processing Record 2 of Set 14 | longkou
# Processing Record 3 of Set 14 | iskitim
# Processing Record 4 of Set 14 | porto torres
# Processing Record 5 of Set 14 | san rafael
# Processing Record 6 of Set 14 | sao felix do xingu
# Processing Record 7 of Set 14 | ust-kuyga
# Processing Record 8 of Set 14 | santa maria
# Processing Record 9 of Set 14 | baglung
# Processing Record 10 of Set 14 | mastic beach
# Processing Record 11 of Set 14 | la ronge
# Processing Record 12 of Set 14 | brigantine
# Processing Record 13 of Set 14 | dicabisagan
# Processing Record 14 of Set 14 | bonthe
# Processing Record 15 of Set 14 | male
# Processing Record 16 of Set 14 | dourbali
# Processing Record 17 of Set 14 | lorengau
# Processing Record 18 of Set 14 | kurilsk
# Processing Record 19 of Set 14 | puri
# Processing Record 20 of Set 14 | wschowa
# Processing Record 21 of Set 14 | soyo
# Processing Record 22 of Set 14 | thanesar
# Processing Record 23 of Set 14 | kamen-rybolov
# Processing Record 24 of Set 14 | soe
# Processing Record 25 of Set 14 | snezhnogorsk
# Processing Record 26 of Set 14 | nantucket
# Processing Record 27 of Set 14 | mitsamiouli
# Processing Record 28 of Set 14 | jacareacanga
# Processing Record 29 of Set 14 | maracaju
# Processing Record 30 of Set 14 | taft
# Processing Record 31 of Set 14 | hamilton
# Processing Record 32 of Set 14 | umm kaddadah
# Processing Record 33 of Set 14 | tateyama
# Processing Record 34 of Set 14 | tucupita
# Processing Record 35 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 14 | conceicao do araguaia
# Processing Record 37 of Set 14 | gudari
# Processing Record 38 of Set 14 | puerto carreno
# Processing Record 39 of Set 14 | dale
# Processing Record 40 of Set 14 | danielskuil
# Processing Record 41 of Set 14 | beloha
# Processing Record 42 of Set 14 | ejea de los caballeros
# Processing Record 43 of Set 14 | waingapu
# Processing Record 44 of Set 14 | itarsi
# Processing Record 45 of Set 14 | khonsa
# Processing Record 46 of Set 14 | santo andre
# Processing Record 47 of Set 14 | arona
# Processing Record 48 of Set 14 | doha
# Processing Record 49 of Set 14 | teeli
# Processing Record 50 of Set 14 | sinazongwe
# Processing Record 1 of Set 15 | santa cruz del sur
# Processing Record 2 of Set 15 | svetlogorsk
# Processing Record 3 of Set 15 | nelson bay
# Processing Record 4 of Set 15 | trelew
# Processing Record 5 of Set 15 | suksun
# Processing Record 6 of Set 15 | taree
# Processing Record 7 of Set 15 | kitakyushu
# Processing Record 8 of Set 15 | yeniseysk
# Processing Record 9 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 15 | perth
# Processing Record 11 of Set 15 | havre
# Processing Record 12 of Set 15 | arlit
# Processing Record 13 of Set 15 | san patricio
# Processing Record 14 of Set 15 | ust-karsk
# Processing Record 15 of Set 15 | itarema
# Processing Record 16 of Set 15 | chara
# Processing Record 17 of Set 15 | santa rosa
# Processing Record 18 of Set 15 | portobelo
# Processing Record 19 of Set 15 | manggar
# Processing Record 20 of Set 15 | goryachegorsk
# Processing Record 21 of Set 15 | fare
# Processing Record 22 of Set 15 | vokhtoga
# Processing Record 23 of Set 15 | silvania
# Processing Record 24 of Set 15 | thinadhoo
# Processing Record 25 of Set 15 | pervoye maya
# Processing Record 26 of Set 15 | puerto escondido
# Processing Record 27 of Set 15 | vostok
# Processing Record 28 of Set 15 | puerto leguizamo
# Processing Record 29 of Set 15 | llangefni
# Processing Record 30 of Set 15 | temuco
# Processing Record 31 of Set 15 | manacapuru
# Processing Record 32 of Set 15 | pingliang
# Processing Record 33 of Set 15 | bull savanna
# Processing Record 34 of Set 15 | zyryanovsk
# Processing Record 35 of Set 15 | makushino
# Processing Record 36 of Set 15 | vaitape
# Processing Record 37 of Set 15 | cibitoke
# Processing Record 38 of Set 15 | gladstone
# Processing Record 39 of Set 15 | astana
# Processing Record 40 of Set 15 | madimba
# Processing Record 41 of Set 15 | easthampton
# Processing Record 42 of Set 15 | bria
# Processing Record 43 of Set 15 | padang
# Processing Record 44 of Set 15 | patiya
# Processing Record 45 of Set 15 | bubaque
# Processing Record 46 of Set 15 | inirida
# Processing Record 47 of Set 15 | atagay
# Processing Record 48 of Set 15 | mareeba
# Processing Record 49 of Set 15 | basco
# Processing Record 50 of Set 15 | nizhniy baskunchak
# Processing Record 1 of Set 16 | ixtapa
# Processing Record 2 of Set 16 | santa ines
# Processing Record 3 of Set 16 | de aar
# Processing Record 4 of Set 16 | erdaojiang
# Processing Record 5 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 16 | estelle
# Processing Record 7 of Set 16 | vanimo
# Processing Record 8 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 16 | stutterheim
# Processing Record 10 of Set 16 | nakhon nayok
# Processing Record 11 of Set 16 | rivne
# Processing Record 12 of Set 16 | mumbwa
# Processing Record 13 of Set 16 | clyde river
# Processing Record 14 of Set 16 | san juan
# Processing Record 15 of Set 16 | victoria point
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# # # Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Hobyo   5.35   48.53     79.45        76          17       16.13
# 1  Bredasdorp -34.53   20.04     55.40        87          10        3.36
# 2      Yulara -25.24  130.99     80.60        42           0       16.11
# 3       Vaini -21.20 -175.20     84.20        66          20       18.34
# 4      Castro -24.79  -50.01     65.17        94          72        3.13
#
#   Country Current Description
# 0      SO          few clouds
# 1      ZA           clear sky
# 2      AU           clear sky
# 3      TO          few clouds
# 4      BR       moderate rain

# %%
#reorder columns
new_col_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_col_order]
city_data_df
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             Hobyo      SO   5.35   48.53     79.45        76          17
# 1        Bredasdorp      ZA -34.53   20.04     55.40        87          10
# 2            Yulara      AU -25.24  130.99     80.60        42           0
# 3             Vaini      TO -21.20 -175.20     84.20        66          20
# 4            Castro      BR -24.79  -50.01     65.17        94          72
# ..              ...     ...    ...     ...       ...       ...         ...
# 701           Rivne      UA  50.62   26.23     32.00        98          95
# 702          Mumbwa      ZM -14.98   27.06     67.46        84          83
# 703     Clyde River      CA  70.47  -68.59     -5.80        83          75
# 704        San Juan      AR -31.54  -68.54     89.22        23           1
# 705  Victoria Point      AU -27.58  153.30     82.00        53           0
#
#      Wind Speed Current Description
# 0         16.13          few clouds
# 1          3.36           clear sky
# 2         16.11           clear sky
# 3         18.34          few clouds
# 4          3.13       moderate rain
# ..          ...                 ...
# 701        5.55     overcast clouds
# 702        1.66       broken clouds
# 703       20.80          light snow
# 704        7.61           clear sky
# 705        7.00           clear sky
#
# [706 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index ="City")
